# %%
import pandas as pd

# %%
list1 = pd.read_csv('csv/CRMLSListing202401.csv')
len(list1)
#27454 rows in January 2024
# Out:
# 27454

# %%
list2 = pd.read_csv('csv/CRMLSListing202402.csv')
len(list2)
#22428 rows in February 2024
# Out:
# 22428

# %%
list3 = pd.read_csv('csv/CRMLSListing202403.csv')
len(list3)
#32282 rows in March 2024
# Out:
# 32282

# %%
list4 = pd.read_csv('csv/CRMLSListing202404.csv')
len(list4)
#36503 rows in April 2024
# Out:
# 36503

# %%
list5 = pd.read_csv('csv/CRMLSListing202405.csv')
len(list5)
#38796 rows in May 2024
# Out:
# 38796

# %%
list6 = pd.read_csv('csv/CRMLSListing202406.csv')
len(list6)
#35893 rows in June 2024
# Out:
# 35893

# %%
list7 = pd.read_csv('csv/CRMLSListing202407.csv')
len(list7)
#36340 rows in July 2024
# Out:
# 36340

# %%
list8 = pd.read_csv('csv/CRMLSListing202408.csv')
len(list8)
#35305 rows in August 2024
# Out:
# 35305

# %%
list9 = pd.read_csv('csv/CRMLSListing202409.csv')
len(list9)
#34625 rows in September 2024
# Out:
# 34625

# %%
list10 = pd.read_csv('csv/CRMLSListing202410.csv')
len(list10)
#34730 rows in October 2024
# Out:
# 34730

# %%
list11 = pd.read_csv('csv/CRMLSListing202411.csv')
len(list11)
#25128 rows in November 2024
# Out:
# 25128

# %%
list12 = pd.read_csv('csv/CRMLSListing202412.csv')
len(list12)
#19417 rows in December 2024
# Out:
# 19417

# %%
list13 = pd.read_csv('csv/CRMLSListing202501.csv')
len(list13)
#37469 rows in January 2025
# Out:
# 37469

# %%
list14 = pd.read_csv('csv/CRMLSListing202502.csv')
len(list14)
#33983 rows in February 2025
# Out:
# 33983

# %%
list15 = pd.read_csv('csv/CRMLSListing202503.csv')
len(list15)
#38492 rows in March 2025
# Out:
# 38492

# %%
list16 = pd.read_csv('csv/CRMLSListing202504.csv')
len(list16)
#40187 rows in April 2025
# Out:
# 40187

# %%
list17 = pd.read_csv('csv/CRMLSListing202505.csv')
len(list17)
#40271 rows in May 2025
# Out:
# 40271

# %%
list18 = pd.read_csv('csv/CRMLSListing202506.csv')
len(list18)
#26399 rows in June 2025
# Out:
# 26399

# %%
list19 = pd.read_csv('csv/CRMLSListing202507.csv')
len(list19)
#27345 rows in July 2025
# Out:
# 27345

# %%
list20 = pd.read_csv('csv/CRMLSListing202508.csv')
len(list20)
#25210 rows in August 2025
# Out:
# 25210

# %%
list21 = pd.read_csv('csv/CRMLSListing202509.csv')
len(list21)
#26923 rows in September 2025
# Out:
# 26923

# %%
list22 = pd.read_csv('csv/CRMLSListing202510.csv')
len(list22)
#27586 rows in October 2025
# Out:
# 27586

# %%
list23 = pd.read_csv('csv/CRMLSListing202511.csv')
len(list23)
#20677 rows in November 2025
# Out:
# 20677

# %%
list24 = pd.read_csv('csv/CRMLSListing202512.csv')
len(list24)
#18773 rows in December 2025
# Out:
# 18773

# %%
list25 = pd.read_csv('csv/CRMLSListing202601.csv')
len(list25)
#35302 rows in January 2026
# Out:
# 35302

# %%
list26 = pd.read_csv('csv/CRMLSListing202602.csv')
len(list26)
#32884 rows in February 2026
# Out:
# C:\Users\niral\AppData\Local\Temp\ipykernel_760\2314442675.py:1: DtypeWarning: Columns (32,58,63,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   list26 = pd.read_csv('csv/CRMLSListing202602.csv')
# 32884

# %%
list27 = pd.read_csv('csv/CRMLSListing202603.csv')
len(list27)
#39153 rows in March 2026
# Out:
# 39153

# %%
list28 = pd.read_csv('csv/CRMLSListing202604.csv')
len(list28)
#39020 rows in April 2026
# Out:
# 39020

# %%
list29 = pd.read_csv('csv/CRMLSListing202605.csv')
len(list29)
#36115 rows in May 2026
# Out:
# 36115

# %%
list30 = pd.read_csv('csv/CRMLSListing202606.csv')
len(list30)
#37455 rows in June 2026
# Out:
# 37455

# %%
listing = pd.concat([list1, list2, list3, list4, list5, list6, list7, list8, list9, list10,
    list11, list12, list13, list14, list15, list16, list17, list18, list19, list20,
    list21, list22, list23, list24, list25, list26, list27, list28, list29, list30])
len(listing)
listing.to_csv('listing.csv', index=False)
#924690 rows after concatenation

# %%
listing_residential = listing[listing["PropertyType"] == "Residential"]
len(listing_residential)
listing_residential.to_csv('listing_residential.csv', index=False)
#589353 rows after residential filter

# %%
sold1 = pd.read_csv('csv/CRMLSSold202401_filled.csv')
len(sold1)
#17958 rows in January 2024
# Out:
# 17958

# %%
sold2 = pd.read_csv('csv/CRMLSSold202402.csv')
len(sold2)
#19925 rows in February 2024
# Out:
# 19925

# %%
sold3 = pd.read_csv('csv/CRMLSSold202403_filled.csv')
len(sold3)
#23276 rows in March 2024
# Out:
# 23276

# %%
sold4 = pd.read_csv('csv/CRMLSSold202404_filled.csv')
len(sold4)
#24640 rows in April 2024
# Out:
# C:\Users\niral\AppData\Local\Temp\ipykernel_760\2636988687.py:1: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold4 = pd.read_csv('csv/CRMLSSold202404_filled.csv')
# 24640

# %%
sold5 = pd.read_csv('csv/CRMLSSold202405_filled.csv')
len(sold5)
#26487 rows in May 2024
# Out:
# 26487

# %%
sold6 = pd.read_csv('csv/CRMLSSold202406_filled.csv')
len(sold6)
#24328 rows in June 2024
# Out:
# 24328

# %%
sold7 = pd.read_csv('csv/CRMLSSold202407_filled.csv')
len(sold7)
#26240 rows in July 2024
# Out:
# 26240

# %%
sold8 = pd.read_csv('csv/CRMLSSold202408.csv')
len(sold8)
#24558 rows in August 2024
# Out:
# 24558

# %%
sold9 = pd.read_csv('csv/CRMLSSold202409.csv')
len(sold9)
#21267 rows in September 2024
# Out:
# 21267

# %%
sold10 = pd.read_csv('csv/CRMLSSold202410.csv')
len(sold10)
#23274 rows in October 2024
# Out:
# 23274

# %%
sold11 = pd.read_csv('csv/CRMLSSold202411.csv')
len(sold11)
#20279 rows in November 2024
# Out:
# 20279

# %%
sold12 = pd.read_csv('csv/CRMLSSold202412.csv')
len(sold12)
#20241 rows in December 2024
# Out:
# 20241

# %%
sold13 = pd.read_csv('csv/CRMLSSold202501_filled.csv')
len(sold13)
#18738 rows in January 2025
# Out:
# 18738

# %%
sold14 = pd.read_csv('csv/CRMLSSold202502.csv')
len(sold14)
#18702 rows in February 2025
# Out:
# 18702

# %%
sold15 = pd.read_csv('csv/CRMLSSold202503.csv')
len(sold15)
#21445 rows in March 2025
# Out:
# 21445

# %%
sold16 = pd.read_csv('csv/CRMLSSold202504.csv')
len(sold16)
#23262 rows in April 2025
# Out:
# 23262

# %%
sold17 = pd.read_csv('csv/CRMLSSold202505.csv')
len(sold17)
#23154 rows in May 2025
# Out:
# 23154

# %%
sold18 = pd.read_csv('csv/CRMLSSold202506.csv')
len(sold18)
#22883 rows in June 2025
# Out:
# C:\Users\niral\AppData\Local\Temp\ipykernel_760\3893529620.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold18 = pd.read_csv('csv/CRMLSSold202506.csv')
# 22883

# %%
sold19 = pd.read_csv('csv/CRMLSSold202507.csv')
len(sold19)
#23646 rows in July 2025
# Out:
# 23646

# %%
sold20 = pd.read_csv('csv/CRMLSSold202508.csv')
len(sold20)
#22972 rows in August 2025
# Out:
# 22972

# %%
sold21 = pd.read_csv('csv/CRMLSSold202509.csv')
len(sold21)
#22443 rows in September 2025
# Out:
# 22443

# %%
sold22 = pd.read_csv('csv/CRMLSSold202510.csv')
len(sold22)
#23233 rows in October 2025
# Out:
# 23233

# %%
sold23 = pd.read_csv('csv/CRMLSSold202511.csv')
len(sold23)
#19088 rows in November 2025
# Out:
# 19088

# %%
sold24 = pd.read_csv('csv/CRMLSSold202512.csv')
len(sold24)
#20538 rows in December 2025
# Out:
# 20538

# %%
sold25 = pd.read_csv('csv/CRMLSSold202601.csv')
len(sold25)
#16487 rows in January 2026
# Out:
# C:\Users\niral\AppData\Local\Temp\ipykernel_760\2292643314.py:1: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold25 = pd.read_csv('csv/CRMLSSold202601.csv')
# 16487

# %%
sold26 = pd.read_csv('csv/CRMLSSold202602.csv')
len(sold26)
#19010 rows in February 2026
# Out:
# 19010

# %%
sold27 = pd.read_csv('csv/CRMLSSold202603.csv')
len(sold27)
#23372 rows in March 2026
# Out:
# 23372

# %%
sold28 = pd.read_csv('csv/CRMLSSold202604.csv')
len(sold28)
#24261 rows in April 2026
# Out:
# 24261

# %%
sold29 = pd.read_csv('csv/CRMLSSold202605.csv')
len(sold29)
#24194 rows in May 2026
# Out:
# 24194

# %%
sold30 = pd.read_csv('csv/CRMLSSold202606.csv')
len(sold30)
#25521 rows in June 2026
# Out:
# 25521

# %%
sold = pd.concat([sold1, sold2, sold3, sold4, sold5, sold6, sold7, sold8, sold9, sold10,
                  sold11, sold12, sold13, sold14, sold15, sold16, sold17, sold18, sold19, sold20,
                  sold21, sold22, sold23, sold24, sold25, sold26, sold27, sold28, sold29, sold30])
len(sold)
sold.to_csv('sold.csv', index = False)
#639901 rows after concatenation

# %%
sold_residential = sold[sold["PropertyType"] == "Residential"]
len(sold_residential)
sold_residential.to_csv('sold_residential.csv', index=False)
#430437 rows after Residential filter

# %%
# Unique property types found
print(sold['PropertyType'].unique())
# Out:
# ['Residential' 'CommercialLease' 'Land' 'ResidentialLease'
#  'ManufacturedInPark' 'ResidentialIncome' 'CommercialSale'
#  'BusinessOpportunity']

# %%
# Filtering logic applied
print(f"Total rows before filter: {len(sold)}")
sold_residential = sold[sold['PropertyType'] == 'Residential']
print(f"Total rows after Residential filter: {len(sold_residential)}")
# Out:
# Total rows before filter: 665422
# Total rows after Residential filter: 447978

# %%
# Null-count summary table
null_counts = sold_residential.isnull().sum()
null_pct = (null_counts / len(sold_residential)) * 100
null_summary = pd.DataFrame({'null_count': null_counts, 'null_pct': null_pct})
print(null_summary)
# Out:
#                               null_count    null_pct
# Flooring                          160684   35.868726
# ViewYN                             38421    8.576537
# WaterfrontYN                      447691   99.935934
# BasementYN                        439195   98.039413
# PoolPrivateYN                      38243    8.536803
# ...                                  ...         ...
# MiddleOrJuniorSchoolDistrict      447978  100.000000
# BuyerAgentAOR                      65718   14.669917
# ListAgentAOR                       57392   12.811343
# OriginatingSystemName             369545   82.491774
# OriginatingSystemSubName          369545   82.491774
#
# [82 rows x 2 columns]

# %%
# Missing value report columns above 90% null
high_null = null_summary[null_summary['null_pct'] > 90]
print("Columns above 90% null:")
print(high_null)
# Out:
# Columns above 90% null:
#                               null_count    null_pct
# WaterfrontYN                      447691   99.935934
# BasementYN                        439195   98.039413
# FireplacesTotal                   447978  100.000000
# AboveGradeFinishedArea            447978  100.000000
# TaxAnnualAmount                   447978  100.000000
# BuilderName                       426046   95.104224
# TaxYear                           447978  100.000000
# BuildingAreaTotal                 416533   92.980682
# ElementarySchoolDistrict          447978  100.000000
# CoBuyerAgentFirstName             406938   90.838836
# BelowGradeFinishedArea            445322   99.407114
# BusinessType                      447978  100.000000
# CoveredSpaces                     447978  100.000000
# LotSizeDimensions                 426162   95.130118
# MiddleOrJuniorSchoolDistrict      447978  100.000000

# %%
# Numeric distribution summary for ClosePrice, LivingArea, DaysOnMarket
cols = ['ClosePrice', 'LivingArea', 'DaysOnMarket']
print(sold_residential[cols].describe(percentiles=[.25, .5, .75]))
# Out:
#          ClosePrice    LivingArea   DaysOnMarket
# count  4.479760e+05  4.477250e+05  447978.000000
# mean   1.192662e+06  1.904294e+03      37.315114
# std    6.058464e+06  2.545551e+04      53.617007
# min    0.000000e+00  0.000000e+00    -288.000000
# 25%    5.750000e+05  1.248000e+03       8.000000
# 50%    8.250000e+05  1.646000e+03      18.000000
# 75%    1.300000e+06  2.224000e+03      48.000000
# max    9.895000e+08  1.702132e+07   12430.000000

# %%
# Save filtered dataset as new CSV
sold_residential.to_csv('sold_residential_week2.csv', index=False)

# %%
listings = pd.read_csv('listing_residential.csv', low_memory=False)

# %%
# Step 1 - Fetch the mortgage rate data from FRED
url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=MORTGAGE30US"
mortgage = pd.read_csv(url, parse_dates=['observation_date'])
mortgage.columns = ['date', 'rate_30yr_fixed']
print(mortgage.head())
# Out:
#         date  rate_30yr_fixed
# 0 1971-04-02             7.33
# 1 1971-04-09             7.31
# 2 1971-04-16             7.31
# 3 1971-04-23             7.31
# 4 1971-04-30             7.29

# %%
# Step 2 - Resample weekly rates to monthly averages
mortgage['year_month'] = mortgage['date'].dt.to_period('M')
mortgage_monthly = (
    mortgage.groupby('year_month')['rate_30yr_fixed']
    .mean()
    .reset_index()
)
print(mortgage_monthly.head())
# Out:
#   year_month  rate_30yr_fixed
# 0    1971-04           7.3100
# 1    1971-05           7.4250
# 2    1971-06           7.5300
# 3    1971-07           7.6040
# 4    1971-08           7.6975

# %%
sold['year_month'] = pd.to_datetime(sold['CloseDate'], format='mixed').dt.to_period('M')

listings['year_month'] = pd.to_datetime(
    listings['ListingContractDate'], format='mixed'
).dt.to_period('M')

# %%
# Step 4 - Merge
sold_with_rates = sold.merge(mortgage_monthly, on='year_month', how='left')
listings_with_rates = listings.merge(mortgage_monthly, on='year_month', how='left')

# %%
# Step 5 - Validate the merge
print(f"Null rates in sold: {sold_with_rates['rate_30yr_fixed'].isnull().sum()}")
print(f"Null rates in listings: {listings_with_rates['rate_30yr_fixed'].isnull().sum()}")
# Out:
# Null rates in sold: 0
# Null rates in listings: 0

# %%
# Save enriched datasets
sold_with_rates.to_csv('sold_with_rates.csv', index=False)
listings_with_rates.to_csv('listings_with_rates.csv', index=False)
print("Saved sold_with_rates.csv and listings_with_rates.csv")
# Out:
# Saved sold_with_rates.csv and listings_with_rates.csv

# %%
# Preview
print(
    sold_with_rates[
        ['CloseDate', 'year_month', 'ClosePrice', 'rate_30yr_fixed']
    ].head()
)
# Out:
#    CloseDate year_month  ClosePrice  rate_30yr_fixed
# 0  1/26/2024    2024-01    240000.0           6.6425
# 1  1/24/2024    2024-01       950.0           6.6425
# 2  1/16/2024    2024-01     45000.0           6.6425
# 3   1/8/2024    2024-01    141500.0           6.6425
# 4  1/17/2024    2024-01     15000.0           6.6425

# %%
# Removing columns above 90% null from missing value report
print(f"Before dropping high null columns: {len(sold_residential)} rows")
sold_residential = sold_residential.drop(columns=['WaterfrontYN', 'BasementYN', 'FireplacesTotal', 'AboveGradeFinishedArea', 'TaxAnnualAmount', 'BuilderName', 'TaxYear', 'BuildingAreaTotal', 'ElementarySchoolDistrict', 'CoBuyerAgentFirstName', 'BelowGradeFinishedArea', 'BusinessType', 'CoveredSpaces', 'LotSizeDimensions', 'MiddleOrJuniorSchoolDistrict'], errors='ignore')
print(f"After dropping high null columns: {len(sold_residential)} rows")
# Out:
# Before dropping high null columns: 447978 rows
# After dropping high null columns: 447978 rows

# %%
# Converting to datetime format for easier analysis
sold_residential['CloseDate'] = pd.to_datetime(sold_residential['CloseDate'], errors='coerce')
sold_residential['PurchaseContractDate'] = pd.to_datetime(sold_residential['PurchaseContractDate'], errors='coerce')
sold_residential['ListingContractDate'] = pd.to_datetime(sold_residential['ListingContractDate'], errors='coerce')
sold_residential['ContractStatusChangeDate'] = pd.to_datetime(sold_residential['ContractStatusChangeDate'], errors='coerce')

# %%
# Checking if listing date is after close date and marks True
sold_residential['listing_after_close_flag'] = sold_residential['ListingContractDate'] > sold_residential['CloseDate']
print(f"Listings after close: {sold_residential['listing_after_close_flag'].sum()}")
# Out:
# Listings after close: 11

# %%
# Checking if purchase contract date is after close date and marks True
sold_residential['purchase_after_close_flag'] = sold_residential['PurchaseContractDate'] > sold_residential['CloseDate']
print(f"Purchases after close: {sold_residential['purchase_after_close_flag'].sum()}")
# Out:
# Purchases after close: 99

# %%
# Marks True if dates are out of order (listing, purchase, close)
sold_residential['negative_timeline_flag'] = (
    sold_residential['ListingContractDate'].notna() &
    sold_residential['PurchaseContractDate'].notna() &
    sold_residential['CloseDate'].notna() &
    (
        (sold_residential['ListingContractDate'] > sold_residential['PurchaseContractDate']) |
        (sold_residential['PurchaseContractDate'] > sold_residential['CloseDate'])
    )
)
print(f"Negative timeline flags: {sold_residential['negative_timeline_flag'].sum()}")
# Out:
# Negative timeline flags: 160

# %%
# Converts to numbers to account for any misread strings
sold_residential['ClosePrice'] = pd.to_numeric(sold_residential['ClosePrice'], errors='coerce')
sold_residential['LivingArea'] = pd.to_numeric(sold_residential['LivingArea'], errors='coerce')
sold_residential['DaysOnMarket'] = pd.to_numeric(sold_residential['DaysOnMarket'], errors='coerce')

# %%
# Removes rows with impossible values
print(f"Before removing impossible values: {len(sold_residential)} rows")
sold_residential = sold_residential[sold_residential['ClosePrice'] > 0]
sold_residential = sold_residential[sold_residential['LivingArea'] > 0]
sold_residential = sold_residential[sold_residential['DaysOnMarket'] >= 0]
sold_residential = sold_residential[sold_residential['BathroomsTotalInteger'] >= 0]
sold_residential = sold_residential[sold_residential['BedroomsTotal'] >= 0]
print(f"After removing impossible values: {len(sold_residential)} rows")
# Out:
# Before removing impossible values: 447978 rows
# After removing impossible values: 447448 rows

# %%
# Converts latitude and longitude to numbers
sold_residential['Longitude'] = pd.to_numeric(sold_residential['Longitude'], errors='coerce')
sold_residential['Latitude'] = pd.to_numeric(sold_residential['Latitude'], errors='coerce')

# %%
# Counts rows with missing coordinates and removes them
print(f"Before removing missing coordinates: {len(sold_residential)} rows")
invalid_coords = sold_residential[sold_residential['Longitude'].isna() | sold_residential['Latitude'].isna()]
sold_residential = sold_residential.dropna(subset=['Longitude', 'Latitude'])
print(f"After removing missing coordinates: {len(sold_residential)} rows")
# Out:
# Before removing missing coordinates: 447448 rows
# After removing missing coordinates: 443077 rows

# %%
# Saves cleaned dataset as a new CSV
sold_residential.to_csv('ResidentialSold_clean.csv', index=False)
print(f"Final cleaned sold dataset: {len(sold_residential)} rows")
# Out:
# Final cleaned sold dataset: 443077 rows

# %%
# Removing columns above 90% null from missing value report
print(f"Before dropping high null columns: {len(listing_residential)} rows")
listing_residential = listing_residential.drop(columns=['WaterfrontYN', 'BasementYN', 'FireplacesTotal', 'AboveGradeFinishedArea', 'TaxAnnualAmount', 'BuilderName', 'TaxYear', 'BuildingAreaTotal', 'ElementarySchoolDistrict', 'CoBuyerAgentFirstName', 'BelowGradeFinishedArea', 'BusinessType', 'CoveredSpaces', 'LotSizeDimensions', 'MiddleOrJuniorSchoolDistrict'], errors='ignore')
print(f"After dropping high null columns: {len(listing_residential)} rows")
# Out:
# Before dropping high null columns: 613434 rows
# After dropping high null columns: 613434 rows

# %%
# Converting to datetime format for easier analysis
listing_residential['CloseDate'] = pd.to_datetime(listing_residential['CloseDate'], errors='coerce')
listing_residential['PurchaseContractDate'] = pd.to_datetime(listing_residential['PurchaseContractDate'], errors='coerce')
listing_residential['ListingContractDate'] = pd.to_datetime(listing_residential['ListingContractDate'], errors='coerce')
listing_residential['ContractStatusChangeDate'] = pd.to_datetime(listing_residential['ContractStatusChangeDate'], errors='coerce')

# %%
# Checking if listing date is after close date and marks True
listing_residential['listing_after_close_flag'] = listing_residential['ListingContractDate'] > listing_residential['CloseDate']
print(f"Listings after close: {listing_residential['listing_after_close_flag'].sum()}")
# Out:
# Listings after close: 84

# %%
# Checking if purchase contract date is after close date and marks True
listing_residential['purchase_after_close_flag'] = listing_residential['PurchaseContractDate'] > listing_residential['CloseDate']
print(f"Purchases after close: {listing_residential['purchase_after_close_flag'].sum()}")
# Out:
# Purchases after close: 255

# %%
# Marks True if dates are out of order (listing, purchase, close)
listing_residential['negative_timeline_flag'] = (
    listing_residential['ListingContractDate'].notna() &
    listing_residential['PurchaseContractDate'].notna() &
    listing_residential['CloseDate'].notna() &
    (
        (listing_residential['ListingContractDate'] > listing_residential['PurchaseContractDate']) |
        (listing_residential['PurchaseContractDate'] > listing_residential['CloseDate'])
    )
)
print(f"Negative timeline flags: {listing_residential['negative_timeline_flag'].sum()}")
# Out:
# Negative timeline flags: 495

# %%
# Converts to numbers to account for any misread strings
listing_residential['ClosePrice'] = pd.to_numeric(listing_residential['ClosePrice'], errors='coerce')
listing_residential['LivingArea'] = pd.to_numeric(listing_residential['LivingArea'], errors='coerce')
listing_residential['DaysOnMarket'] = pd.to_numeric(listing_residential['DaysOnMarket'], errors='coerce')

# %%
# Removes rows with impossible values
print(f"Before removing impossible values: {len(listing_residential)} rows")
listing_residential = listing_residential[listing_residential['LivingArea'] > 0]
listing_residential = listing_residential[listing_residential['DaysOnMarket'] >= 0]
listing_residential = listing_residential[listing_residential['BathroomsTotalInteger'] >= 0]
listing_residential = listing_residential[listing_residential['BedroomsTotal'] >= 0]
print(f"After removing impossible values: {len(listing_residential)} rows")
# Out:
# Before removing impossible values: 613434 rows
# After removing impossible values: 612309 rows

# %%
# Converts latitude and longitude to numbers
listing_residential['Longitude'] = pd.to_numeric(listing_residential['Longitude'], errors='coerce')
listing_residential['Latitude'] = pd.to_numeric(listing_residential['Latitude'], errors='coerce')

# %%
# Counts rows with missing coordinates and removes them
print(f"Before removing missing coordinates: {len(listing_residential)} rows")
invalid_coords = listing_residential[listing_residential['Longitude'].isna() | listing_residential['Latitude'].isna()]
listing_residential = listing_residential.dropna(subset=['Longitude', 'Latitude'])
print(f"After removing missing coordinates: {len(listing_residential)} rows")
# Out:
# Before removing missing coordinates: 612309 rows
# After removing missing coordinates: 531408 rows

# %%
# Saves cleaned dataset as a new CSV
listing_residential.to_csv('ResidentialListing_clean.csv', index=False)
print(f"Final cleaned listing dataset: {len(listing_residential)} rows")
# Out:
# Final cleaned listing dataset: 531408 rows

# %%
# Confirming data types after conversion
print(sold_residential.dtypes)
print(listing_residential.dtypes)
# Out:
# Flooring                      object
# ViewYN                        object
# PoolPrivateYN                 object
# OriginalListPrice            float64
# ListingKey                     int64
#                               ...
# OriginatingSystemName         object
# OriginatingSystemSubName      object
# listing_after_close_flag        bool
# purchase_after_close_flag       bool
# negative_timeline_flag          bool
# Length: 70, dtype: object
# OriginalListPrice                   float64
# ListingKey                            int64
# ListAgentEmail                       object
# CloseDate                    datetime64[ns]
# ClosePrice                          float64
#                                   ...
# LotSizeSquareFeet                   float64
# UnparsedAddress.1                    object
# listing_after_close_flag               bool
# purchase_after_close_flag              bool
# negative_timeline_flag                 bool
# Length: 74, dtype: object

# %%
# Price Ratio - measures negotiation strength
sold_residential['price_ratio'] = sold_residential['ClosePrice'] / sold_residential['OriginalListPrice']

# %%
# Price Per Square Foot - normalizes price across sizes
sold_residential['price_per_sqft'] = sold_residential['ClosePrice'] / sold_residential['LivingArea']

# %%
# Year, Month, and YrMo derived from CloseDate - enables time series analysis
sold_residential['Year'] = sold_residential['CloseDate'].dt.year
sold_residential['Month'] = sold_residential['CloseDate'].dt.month
sold_residential['YrMo'] = sold_residential['CloseDate'].dt.to_period('M')

# %%
# Listing to Contract Days - measures time from listing to accepted offer
sold_residential['listing_to_contract_days'] = (sold_residential['PurchaseContractDate'] - sold_residential['ListingContractDate']).dt.days

# %%
# Contract to Close Days - escrow and closing period duration
sold_residential['contract_to_close_days'] = (sold_residential['CloseDate'] - sold_residential['PurchaseContractDate']).dt.days

# %%
# Sample output table showing new columns populated correctly
print(sold_residential[['ClosePrice', 'OriginalListPrice', 'price_ratio', 'price_per_sqft', 'Year', 'Month', 'YrMo', 'listing_to_contract_days', 'contract_to_close_days']].head())
# Out:
#     ClosePrice  OriginalListPrice  price_ratio  price_per_sqft    Year  Month  \
# 0     240000.0           499000.0     0.480962      210.526316  2024.0    1.0
# 5     815000.0           759900.0     1.072510      412.867275  2024.0    1.0
# 9     810000.0           739900.0     1.094743      410.334347  2024.0    1.0
# 28   2100000.0          2100000.0     1.000000      562.098501  2024.0    1.0
# 31   2340000.0                NaN          NaN      958.230958  2024.0    1.0
#
#        YrMo  listing_to_contract_days  contract_to_close_days
# 0   2024-01                     777.0                    65.0
# 5   2024-01                     114.0                   919.0
# 9   2024-01                     255.0                   778.0
# 28  2024-01                       0.0                    48.0
# 31  2024-01                      33.0                   -33.0

# %%
# Segmented summary table grouped by CountyOrParish
county_summary = sold_residential.groupby('CountyOrParish').agg(
    avg_close_price=('ClosePrice', 'mean'),
    avg_price_ratio=('price_ratio', 'mean'),
    avg_price_per_sqft=('price_per_sqft', 'mean'),
    avg_days_on_market=('DaysOnMarket', 'mean'),
    avg_listing_to_contract=('listing_to_contract_days', 'mean'),
    avg_contract_to_close=('contract_to_close_days', 'mean'),
    total_sales=('ClosePrice', 'count')
).reset_index()

print(county_summary)
# Out:
#    CountyOrParish  avg_close_price  avg_price_ratio  avg_price_per_sqft  \
# 0         Alameda     1.316049e+06         1.234375          775.110634
# 1          Alpine     1.100000e+06         0.666667          267.119961
# 2          Amador     4.132854e+05         0.880539          223.854022
# 3           Butte     4.342954e+05         1.422779          261.820616
# 4       Calaveras     5.440068e+05         0.927142          275.300015
# ..            ...              ...              ...                 ...
# 58         Tulare     4.416454e+05        12.725770          241.405154
# 59       Tuolumne     4.653630e+05         0.949554          266.094561
# 60        Ventura     1.076312e+06         1.438885          615.716577
# 61           Yolo     6.086756e+05         0.979385          344.919715
# 62           Yuba     4.211159e+05         0.949836          251.051809
#
#     avg_days_on_market  avg_listing_to_contract  avg_contract_to_close  \
# 0            25.720624                22.412232              26.429309
# 1           231.000000               231.000000              32.000000
# 2           120.520000                57.800000              31.400000
# 3            52.512605                51.448242              35.193359
# 4            61.132075                56.500000              36.681818
# ..                 ...                      ...                    ...
# 58           43.338384                38.931034              35.482759
# 59           72.215470               102.260870              44.826087
# 60           43.008855                44.912906              25.565163
# 61           39.951807                31.727273              35.909091
# 62           67.359281                59.756757              29.621622
#
#     total_sales
# 0         20510
# 1             1
# 2            25
# 3          4522
# 4           106
# ..          ...
# 58          396
# 59          181
# 60        14003
# 61           83
# 62          167
#
# [63 rows x 8 columns]

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (1.1.4)
# Requirement already satisfied: numpy>=1.24 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (2.3.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (0.13.0)
# Requirement already satisfied: packaging in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\niral\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd

# Read the school district GeoJSON
district_areas = gpd.read_file('California_School_District_Areas_2024-25.geojson')

# Filter to Unified districts only
unified_districts = district_areas[district_areas['DistrictType'] == 'Unified'].copy()

# %%
# Convert sold_residential to GeoDataFrame using Latitude and Longitude
gdf = gpd.GeoDataFrame(
    sold_residential,
    geometry=gpd.points_from_xy(sold_residential['Longitude'], sold_residential['Latitude']),
    crs="EPSG:4326"
)

# Align coordinate systems
if gdf.crs != unified_districts.crs:
    unified_districts = unified_districts.to_crs(gdf.crs)

# %%
# Spatial join - find which school district each property is in
joined = gpd.sjoin(
    gdf,
    unified_districts[['DistrictName', 'geometry']],
    how="left",
    predicate="within"
)

# Drop duplicates keeping first match, then add DistrictName
joined = joined[~joined.index.duplicated(keep='first')]
sold_residential['DistrictName'] = joined['DistrictName']
print(f"Properties with district assigned: {sold_residential['DistrictName'].notna().sum()}")
# Out:
# Properties with district assigned: 6665234

# %%
# Save final enriched dataset as CSV
sold_residential.to_csv('ResidentialSold_clean.csv', index=False)
print(f"Saved final dataset with {len(sold_residential)} rows")
# Out:
# Saved final dataset with 8725341 rows

# %%
# Segmented summary table grouped by CountyOrParish
county_summary = sold_residential.groupby('CountyOrParish').agg(
    avg_close_price=('ClosePrice', 'mean'),
    avg_price_ratio=('price_ratio', 'mean'),
    avg_price_per_sqft=('price_per_sqft', 'mean'),
    avg_days_on_market=('DaysOnMarket', 'mean'),
    avg_listing_to_contract=('listing_to_contract_days', 'mean'),
    avg_contract_to_close=('contract_to_close_days', 'mean'),
    total_sales=('ClosePrice', 'count')
).reset_index()

print(county_summary)
# Out:
#    CountyOrParish  avg_close_price  avg_price_ratio  avg_price_per_sqft  \
# 0         Alameda     1.319613e+06         1.246617          779.541739
# 1          Alpine     1.100000e+06         0.666667          267.119961
# 2          Amador     4.056777e+05         0.891756          223.699673
# 3           Butte     4.356488e+05         1.371061          264.494036
# 4       Calaveras     5.335051e+05         0.930089          272.165463
# ..            ...              ...              ...                 ...
# 58         Tulare     4.419453e+05        11.922785          242.082300
# 59       Tuolumne     4.578778e+05         0.951367          264.636991
# 60        Ventura     1.055752e+06         1.454629          619.481660
# 61           Yolo     6.162536e+05         0.979094          350.723150
# 62           Yuba     4.165791e+05         0.959868          252.638597
#
#     avg_days_on_market  avg_listing_to_contract  avg_contract_to_close  \
# 0            24.690858                20.663363              25.871946
# 1           231.000000               231.000000              32.000000
# 2           106.387255                45.956522              30.434783
# 3            42.800399                39.335538              34.329241
# 4            52.548899                50.782016              30.405995
# ..                 ...                      ...                    ...
# 58           37.910751                31.388122              34.370126
# 59           62.727515                81.877922              43.706494
# 60           39.271421                38.705294              24.849357
# 61           35.294192                27.820350              36.799682
# 62           53.265512                49.378873              28.914085
#
#     total_sales
# 0        412587
# 1             2
# 2           408
# 3         85816
# 4          1953
# ..          ...
# 58         7832
# 59         3002
# 60       279776
# 61         1584
# 62         3175
#
# [63 rows x 8 columns]

# %%
# IQR outlier detection for ClosePrice
Q1_price = sold_residential['ClosePrice'].quantile(0.25)
Q3_price = sold_residential['ClosePrice'].quantile(0.75)
IQR_price = Q3_price - Q1_price
lower_price = Q1_price - 1.5 * IQR_price
upper_price = Q3_price + 1.5 * IQR_price
sold_residential['outlier_ClosePrice'] = ~sold_residential['ClosePrice'].between(lower_price, upper_price)

# %%
# IQR outlier detection for LivingArea
Q1_area = sold_residential['LivingArea'].quantile(0.25)
Q3_area = sold_residential['LivingArea'].quantile(0.75)
IQR_area = Q3_area - Q1_area
lower_area = Q1_area - 1.5 * IQR_area
upper_area = Q3_area + 1.5 * IQR_area
sold_residential['outlier_LivingArea'] = ~sold_residential['LivingArea'].between(lower_area, upper_area)

# %%
# IQR outlier detection for DaysOnMarket
Q1_dom = sold_residential['DaysOnMarket'].quantile(0.25)
Q3_dom = sold_residential['DaysOnMarket'].quantile(0.75)
IQR_dom = Q3_dom - Q1_dom
lower_dom = Q1_dom - 1.5 * IQR_dom
upper_dom = Q3_dom + 1.5 * IQR_dom
sold_residential['outlier_DaysOnMarket'] = ~sold_residential['DaysOnMarket'].between(lower_dom, upper_dom)

# %%
# Save full flagged dataset
sold_residential.to_csv('ResidentialSold_flagged.csv', index=False)
print(f"Flagged dataset saved with {len(sold_residential)} rows")
# Out:
# Flagged dataset saved with 8725341 rows

# %%
# Create clean filtered dataset with outliers removed
sold_clean = sold_residential[
    ~sold_residential['outlier_ClosePrice'] &
    ~sold_residential['outlier_LivingArea'] &
    ~sold_residential['outlier_DaysOnMarket']
]
sold_clean.to_csv('ResidentialSold_filtered.csv', index=False)
print(f"Filtered dataset saved with {len(sold_clean)} rows")
# Out:
# Filtered dataset saved with 7406959 rows

# %%
# Written comparison before and after filtering
print(f"Before filtering: {len(sold_residential)} rows")
print(f"After filtering: {len(sold_clean)} rows")
print(f"Rows removed: {len(sold_residential) - len(sold_clean)}")
print(f"\nMedian ClosePrice before: {sold_residential['ClosePrice'].median()}")
print(f"Median ClosePrice after: {sold_clean['ClosePrice'].median()}")
print(f"\nMedian LivingArea before: {sold_residential['LivingArea'].median()}")
print(f"Median LivingArea after: {sold_clean['LivingArea'].median()}")
print(f"\nMedian DaysOnMarket before: {sold_residential['DaysOnMarket'].median()}")
print(f"Median DaysOnMarket after: {sold_clean['DaysOnMarket'].median()}")
# Out:
# Before filtering: 8725341 rows
# After filtering: 7406959 rows
# Rows removed: 1318382
#
# Median ClosePrice before: 825000.0
# Median ClosePrice after: 790000.0
#
# Median LivingArea before: 1643.0
# Median LivingArea after: 1571.0
#
# Median DaysOnMarket before: 18.0
# Median DaysOnMarket after: 16.0
